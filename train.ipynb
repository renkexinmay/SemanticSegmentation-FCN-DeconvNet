# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !pip3 install torch torchvision
# Out:
# ...
#     100% |████████████████████████████████| 591.8MB 31kB/s
# tcmalloc: large alloc 1073750016 bytes == 0x60b42000 @  0x7f342ef5d2a4 0x591a07 0x5b5d56 0x502e9a 0x506859 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x504c28 0x502540 0x502f3d 0x507641
# ...
#     100% |████████████████████████████████| 61kB 25.5MB/s
# ...
#     100% |████████████████████████████████| 2.0MB 6.8MB/s
# ...
#   Found existing installation: Pillow 4.0.0
#     Uninstalling Pillow-4.0.0:
#       Successfully uninstalled Pillow-4.0.0
# ...
# WARNING: The following packages were previously imported in this runtime:
#   [PIL]
# You must restart the runtime in order to use newly installed versions.

# %%
import PIL
print(PIL.PILLOW_VERSION)
## MUST BE 5.4.1
## Ctrl+M to reload environment
# Out:
# 5.4.1

# %%
# %cd gdrive/My\ Drive/convdeconvsemanticseg-master
# Out:
# /content/gdrive/My Drive/convdeconvsemanticseg-master

# %%
ls
# Out:
#  BasicModule.py         FCN8s.py          __pycache__/
#  checkpoints/           kexin-fcn/        README.md
#  Colab-Corentin.ipynb   loss.png          results/
#  Colab-Kexin.ipynb      model.py         'train_added_stuff (1).py'
#  Colab-Pierre.ipynb     pascal_voc_seg/   train_added_stuff.py
#  data/                  presentation/     voc.py

# %%
########!rm -rfv results/DeconvNet/saved_images/*

# %%
# !python train_added_stuff.py
# Out:
# PIL Version: 5.4.1 WARNING : make sure it is 5.4.1 and not 4.0.0
# we are actually using : cuda
# Number of training images: 1464
# Number of validation images: 1449
# Model name: FCN_net_v3
# Loss name: CrossEntropyLoss
#
# EPOCH 0 of 100
#
# EPOCH: 0 batch_idx: 0 out of: 23
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2504: UserWarning: nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.")
# label
# torch.Size([64, 224, 224])
# test
# (224, 224, 3)
# tensor(0, device='cuda:0') tensor(20, device='cuda:0') torch.Size([64, 224, 224]) torch.Size([64, 21, 224, 224])
# tensor(-5.0647, device='cuda:0', grad_fn=<MinBackward1>) tensor(4.8700, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(0, device='cuda:0') tensor(20, device='cuda:0') torch.Size([64, 224, 224]) torch.Size([64, 21, 224, 224])
# ...

# %%
# !wget https://raw.githubusercontent.com/ycszen/pytorch-segmentation/master/gcn.py
# Out:
# --2019-01-24 13:26:13--  https://raw.githubusercontent.com/ycszen/pytorch-segmentation/master/gcn.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4372 (4.3K) [text/plain]
# Saving to: ‘gcn.py’
#
# gcn.py              100%[===================>]   4.27K  --.-KB/s    in 0.001s
#
# 2019-01-24 13:26:14 (5.60 MB/s) - ‘gcn.py’ saved [4372/4372]

# %%
# !python remove_gt_colormap.py

# %%
# !bash ./download_and_convert_voc2012.sh

# %%
ls

# %%
cd checkpoints/

# %%
#!pip uninstall -y Pillow
#!pip install Pillow==5.4.1
import PIL
print(PIL.PILLOW_VERSION)

# %%
import PIL
from PIL import Image
print(PIL.PILLOW_VERSION)
# Out:
# 5.4.1

# %%
img = Image.open("./data/VOCdevkit/VOC2012/JPEGImages/2010_003529.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-a831a9edbe2d> in <module>()
# ----> 1 img = Image.open("./data/VOCdevkit/VOC2012/JPEGImages/2010_003529.jpg")
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2632
#    2633     if filename:
# -> 2634         fp = builtins.open(filename, "rb")
#    2635         exclusive_fp = True
#    2636
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/VOCdevkit/VOC2012/JPEGImages/2010_003529.jpg'

# %%
img.save('./data')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-28c2831b94db> in <module>()
# ----> 1 img.save('./data')
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    1710         new_positions = [0]*256
#    1711
# -> 1712         # pick only the used colors from the palette
#    1713         for i, oldPosition in enumerate(dest_map):
#    1714             palette_bytes += real_source_palette[oldPosition*3:oldPosition*3+3]
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in init()
#     396     try:
#     397         from . import PpmImagePlugin
# --> 398         assert PpmImagePlugin
#     399     except ImportError:
#     400         pass
#
# /usr/local/lib/python3.6/dist-packages/PIL/MspImagePlugin.py in <module>()
#     151
#     152
# --> 153 Image.register_decoder('MSP', MspDecoder)
#     154
#     155
#
# ...

# %%
import os

# %%
split_f = './data/VOCdevkit/VOC2012/ImageSets/Segmentation/train.txt'
with open(os.path.join(split_f), "r") as f:
            file_names = [x.strip() for x in f.readlines()]
file_images = [os.path.join('./data/VOCdevkit/VOC2012/JPEGImages', x + ".jpg") for x in file_names]
for name in file_images:
  try:
    img = Image.open(name)
  except:
    print(name)
# Out:
# ['./data/VOCdevkit/VOC2012/JPEGImages/2007_000032.jpg', './data/VOCdevkit/VOC2012/JPEGImages/2007_000039.jpg', './data/VOCdevkit/VOC2012/JPEGImages/2007_000063.jpg', './data/VOCdevkit/VOC2012/JPEGImages/2007_000068.jpg', './data/VOCdevkit/VOC2012/JPEGImages/2007_000121.jpg', './data/VOCdevkit/VOC2012/JPEGImages/2007_000170.jpg', './data/VOCdevkit/VOC2012/JPEGImages/2007_000241.jpg', './data/VOCdevkit/VOC2012/JPEGImages/2007_000243.jpg', './data/VOCdevkit/VOC2012/JPEGImages/2007_000250.jpg', './data/VOCdevkit/VOC2012/JPEGImages/2007_000256.jpg', './data/VOCdevkit/VOC2012/JPEGImages/2007_000333.jpg', './data/VOCdevkit/VOC2012/JPEGImages/2007_000363.jpg', './data/VOCdevkit/VOC2012/JPEGImages/2007_000364.jpg', './data/VOCdevkit/VOC2012/JPEGImages/2007_000392.jpg', './data/VOCdevkit/VOC2012/JPEGImages/2007_000480.jpg', './data/VOCdevkit/VOC2012/JPEGImages/2007_000504.jpg', './data/VOCdevkit/VOC2012/JPEGImages/2007_000515.jpg', './data/VOCdevkit/VOC2012/JPEGImages/2007_000528.jpg', './data
# ...

# %%
1e-3
# Out:
# 0.001

# %%
cd results/FCN_net_v2/log/
# Out:
# /content/gdrive/My Drive/convdeconvsemanticseg-master/results/FCN_net_v2/log

# %%
ls
# Out:
# log.txt

# %%
cd ..
# Out:
# /content/gdrive/My Drive/convdeconvsemanticseg-master
